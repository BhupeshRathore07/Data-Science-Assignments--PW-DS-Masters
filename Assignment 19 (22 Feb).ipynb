# %% [markdown]
# Go to this given URL and solve the following questions
# URL: https://www.youtube.com/@PW-Foundation/videos

# %% [markdown]
# #### Q1. Write a python program to extract the video URL of the first five videos.

# %% [markdown]
# #### Q2. Write a python program to extract the URL of the video thumbnails of the first five videos.

# %% [markdown]
# #### Q3. Write a python program to extract the title of the first five videos.

# %% [markdown]
# #### Q4. Write a python program to extract the number of views of the first five videos.

# %% [markdown]
# #### Q5. Write a python program to extract the time of posting of video for the first five videos.

# %% [markdown]
# Note: Save all the data scraped in the above questions in a CSV file.
#
# Create a simple UI with all functionalities mentioned above and deploy it in AWS.
#
# Note: Create your assignment in Jupyter notebook and upload it to GitHub & share that uploaded
# assignment file link through your dashboard. Make sure the repository is public. Submit your
# deployment link as well.

# %% [markdown]
# ##### Ans:
#
# The sub part of code where all the code for above questions is answered:

# %% [markdown]
# ![image.png](attachment:f42f744f-ce2f-4deb-bed6-b38554ebe9a3.png)

# %% [markdown]
# Deployment Link: https://scrap-youtube.azurewebsites.net
#
# Github Repo link: https://github.com/BhupeshRathore07/Youtube_Scrapper
#
# NB: It Take 45-60 seconds
