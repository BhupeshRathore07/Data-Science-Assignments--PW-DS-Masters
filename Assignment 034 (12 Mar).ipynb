# %% [markdown]
# #### Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5 using Python. Interpret the results.

# %%
import scipy.stats as stats

data = [50]
n = len(data) 
mean = sum(data) / n 
std = 5 
alpha = 0.05 
z = stats.norm.ppf(1 - alpha/2)

lower = mean - z * (std / n**0.5)
upper = mean + z * (std / n**0.5)

print("95% confidence interval:", (lower, upper))
# Out:
# 95% confidence interval: (40.200180077299734, 59.799819922700266)

# %% [markdown]
# #### Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20% brown. Use Python to perform the test with a significance level of 0.05.

# %%
import scipy.stats as stats
import numpy as np

observed_counts = [18, 22, 19, 9, 11, 21]

expected_props = [0.2, 0.2, 0.2, 0.1, 0.1, 0.2]

n = sum(observed_counts)

expected_counts = [prop * n for prop in expected_props]

chi2, p = stats.chisquare(observed_counts, f_exp=expected_counts)

df = len(observed_counts) - 1

critical_value = stats.chi2.ppf(0.95, df)

if chi2 > critical_value:
    print("Reject null hypothesis.")
else:
    print("Fail to reject null hypothesis.")
# Out:
# Fail to reject null hypothesis.

# %% [markdown]
# #### Q3. Use Python to calculate the chi-square statistic and p-value for a contingency table with the following data:
# ![image.png](attachment:2cebeb5e-791f-4781-8906-a85bd60814aa.png)
# #### Interpret the results of the test.

# %%
from scipy.stats import chi2_contingency

obs = [[20, 15], [10, 25], [15, 20]]
chi2, p, dof, expected = chi2_contingency(obs)
print("Chi-square statistic:", chi2)
print("p-value:", p)
# Out:
# Chi-square statistic: 5.833333333333334
# p-value: 0.05411376622282158

# %% [markdown]
# #### Q4. A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the population who smoke.

# %%
from statsmodels.stats.proportion import proportion_confint

n = 500
smokers = 60

conf_int = proportion_confint(smokers, n, alpha=0.05, method='wilson')
print("95% Confidence Interval:", conf_int)
# Out:
# 95% Confidence Interval: (0.09437490012636912, 0.1514195986244106)

# %% [markdown]
# #### Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation of 12 using Python. Interpret the results.

# %%
import scipy.stats as stats

n = 50  
x_bar = 75  
s = 12  
alpha = 0.1  
dof = n - 1  

t = stats.t.ppf(1 - alpha/2, dof)  

lower = x_bar - t * (s / (n**0.5))
upper = x_bar + t * (s / (n**0.5))

print("90% confidence interval:", (lower, upper))
# Out:
# 90% confidence interval: (72.15479878877537, 77.84520121122463)

# %% [markdown]
# #### Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the area corresponding to a chi-square statistic of 15.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

dof = 10

x = np.linspace(0, 30, 500)
y = chi2.pdf(x, dof)
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(x, y, label='Chi-Square Distribution')
x_fill = np.linspace(15, 30, 100)
y_fill = chi2.pdf(x_fill, dof)
ax.fill_between(x_fill, y_fill, 0, alpha=0.5, label='Chi-Square Statistic of 15')

ax.set_xlabel('Chi-Square Statistic')
ax.set_ylabel('Probability Density')
ax.set_title('Chi-Square Distribution with 10 Degrees of Freedom')
ax.legend(loc='best')
plt.show()

# %% [markdown]
# #### Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520 preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who prefer Coke.

# %%
import math

p = 520/1000
n = 1000
z = 2.576

ci_lower = p - z*(math.sqrt((p*(1-p))/n))
ci_upper = p + z*(math.sqrt((p*(1-p))/n))

print("The 99% confidence interval for the true proportion of people who prefer Coke is:")
print("Lower bound:", ci_lower)
print("Upper bound:", ci_upper)
# Out:
# The 99% confidence interval for the true proportion of people who prefer Coke is:
# Lower bound: 0.47930246089012263
# Upper bound: 0.5606975391098774

# %% [markdown]
# #### Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe 45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the expected frequencies of a fair coin. Use a significance level of 0.05.

# %%
from scipy.stats import chisquare

observed = [45, 55]
expected = [50, 50]

chi2, p = chisquare(observed, f_exp=expected)

print("Chi-square statistic:", chi2)
print("p-value:", p)
# Out:
# Chi-square statistic: 1.0
# p-value: 0.31731050786291115

# %% [markdown]
# #### Q9. A study was conducted to determine if there is an association between smoking status (smoker or non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below. Conduct a chi-square test for independence to determine if there is a significant association between smoking status and lung cancer diagnosis.
# ![image.png](attachment:260629f8-1107-47af-b049-b409c3f05b68.png)
# #### Use a significance level of 0.05.

# %%
from scipy.stats import chi2_contingency

data = [[60, 140], [30, 170]]

chi2, pval, dof, expected = chi2_contingency(data)

print("Chi-square test statistic: ", chi2)
print("P-value: ", pval)
print("Degrees of freedom: ", dof)
print("Expected frequencies: ", expected)
# Out:
# Chi-square test statistic:  12.057347670250895
# P-value:  0.0005158863863703744
# Degrees of freedom:  1
# Expected frequencies:  [[ 45. 155.]
#  [ 45. 155.]]

# %% [markdown]
# #### Q10. A study was conducted to determine if the proportion of people who prefer milk chocolate, dark chocolate, or white chocolate is different in the U.S. versus the U.K. A random sample of 500 people from he U.S. and a random sample of 500 people from the U.K. were surveyed. The results are shown in the ontingency table below. Conduct a chi-square test for independence to determine if there is a significant ssociation between chocolate preference and country of origin.
# ![image.png](attachment:4e06e697-6281-49f4-a278-62595484cd47.png)
# #### Use a significance level of 0.01.

# %%
from scipy.stats import chi2_contingency

data = [[200, 150, 150], [225, 175, 100]]

stat, p, dof, expected = chi2_contingency(data)

print("Chi-square statistic: ", stat)
print("p-value: ", p)
# Out:
# Chi-square statistic:  13.393665158371041
# p-value:  0.0012348168997745918

# %% [markdown]
# #### Q11. A random sample of 30 people was selected from a population with an unknown mean and standard deviation. The sample mean was found to be 72 and the sample standard deviation was found to be 10. Conduct a hypothesis test to determine if the population mean is significantly different from 70. Use a significance level of 0.05.

# %%
from scipy import stats

p_value = 2 * stats.t.sf(abs(1.4142), 29)
print("p-value:", p_value)
# Out:
# p-value: 0.16795005771854363
